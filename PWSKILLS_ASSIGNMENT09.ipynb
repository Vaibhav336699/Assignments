# %% [markdown]
# Q1) Explain why we have to use the Exception class while creating a Custom Exception.

# %%
# In Python, when creating custom exceptions, it's recommended to inherit from the base Exception class or one of its subclasses. Here's why:

#Consistency and Interoperability
#Compatibility with Exception Handling Mechanisms
#Future Compatibility
#Documentation and Tooling Support

# %% [markdown]
# Q2) Write a python program to print Python Exception Hierarchy.

# %%
#
#In Python, exceptions are organized in a hierarchy, with base exception classes at the top and more specific exception classes derived from them. The base class for all built-in exceptions is BaseException. 
#Here's a Python program to print the exception hierarchy

def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent, exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 2)

# Print the Python Exception Hierarchy
print("Python Exception Hierarchy:")
print_exception_hierarchy(BaseException)
# Out:
# Python Exception Hierarchy:
#  BaseException
#    Exception
#      TypeError
#        MultipartConversionError
#        FloatOperation
#      StopAsyncIteration
#      StopIteration
#      ImportError
#        ModuleNotFoundError
#        ZipImportError
#      OSError
#        ConnectionError
#          BrokenPipeError
#          ConnectionAbortedError
#          ConnectionRefusedError
#          ConnectionResetError
#            RemoteDisconnected
#        BlockingIOError
#        ChildProcessError
#        FileExistsError
#        FileNotFoundError
#        IsADirectoryError
#        NotADirectoryError
#        InterruptedError
#          InterruptedSystemCall
#        PermissionError
#        ProcessLookupError
#        TimeoutError
#        UnsupportedOperation
#        herror
#        gaierror
#        timeout
#        Error
#          SameFileError
#        SpecialFileError
#        ExecError
#        ReadError
#        SSLError
#          SSLCertVerificationError
# ...

# %% [markdown]
# Q3) What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
# The ArithmeticError class in Python represents errors that occur during arithmetic operations

# Two common errors defined in the ArithmeticError class are ZeroDivisionError and OverflowError.

# ZeroDivisionError:
#This error occurs when attempting to divide a number by zero.
#It is raised when the denominator in a division operation is zero.
#Example:
try:
    result = 10 / 0  # Attempting to divide by zero
except ZeroDivisionError as e:
    print("Error:", e)  # Output: Error: division by zero

    
# OverflowError:
#This error occurs when the result of an arithmetic operation exceeds the maximum representable value for a numeric type.
#It typically occurs in operations involving large integers or floating-point numbers.
#Example:  

try:
    result = 2 ** 1000  # Attempting to calculate 2 raised to the power of 1000
except OverflowError as e:
    print("Error:", e)  # Output: Error: (34, 'Result too large')

# %% [markdown]
# Q4) why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
# The LookupError class in Python serves as a base class for exceptions that occur when a key or index is not found during a lookup operation.

# Two common errors derived from the LookupError class are KeyError and IndexError.

# KeyError:
# This error occurs when attempting to access a key that does not exist in a dictionary.
# It is raised when using square brackets to access a key that is not present in the dictionary.

# IndexError:
# This error occurs when attempting to access an index that is out of range in a sequence (e.g., list, tuple, string).
# It is raised when using square brackets to access an index that is beyond the length of the sequence.

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %%
# ImportError:
# ImportError is a base class for exceptions that occur when attempting to import a module or a specific symbol (e.g., function, class) from a module.

# ModuleNotFoundError:
# ModuleNotFoundError is a subclass of ImportError introduced in Python 3.6.
# It specifically represents an exception that occurs when a module could not be found during the import process

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %%
#Specificity
#Avoid Bare Except
#Use try-except Blocks Sparingly
#Separate Concerns:
#Logging
